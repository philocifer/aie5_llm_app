# %% [markdown]
# # Prompt Engineering and Prototyping Best Practices

# %% [markdown]
# # Session 1 Assignment: Vibe Check

# %% [markdown]
# ##### 🏗️ Activity #1:
#
# Please evaluate your system on the following questions:
#
# 1. Explain the concept of object-oriented programming in simple terms to a complete beginner.
# 2. Read the following paragraph and provide a concise summary of the key points…
# 3. Write a short, imaginative story (100–150 words) about a robot finding friendship in an unexpected place.
# 4. If a store sells apples in packs of 4 and oranges in packs of 3, how many packs of each do I need to buy to get exactly 12 apples and 9 oranges?
# 5. Rewrite the following paragraph in a professional, formal tone…

# %% [markdown]
# ### 1. Explain the concept of object-oriented programming in simple terms to a complete beginner

# %% [markdown]
# Aspect Tested:
# Clarity: Make it easy to understand for a complete beginner.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation: Technical terms are used without much explanation so it's not clear for a complete beginner.

# %% [markdown]
# ### 2. Read the following paragraph and provide a concise summary of the key points…

# %% [markdown]
# Aspect Tested: Conciseness: Be brief and to the point.

# %% [markdown]
# Paragraph:
# The validity of medical studies based on real-world clinical data, such as observational studies, depends on critical assumptions necessary for drawing causal conclusions about medical interventions. Many published studies are flawed because they violate these assumptions and entail biases such as residual confounding, selection bias, and misalignment between treatment and measurement times. Although researchers are aware of these pitfalls, they continue to occur because anticipating and addressing them in the context of a specific study can be challenging without a large, often unwieldy, interdisciplinary team with extensive expertise. To address this expertise gap, we explore the use of large language models (LLMs) as co-pilot tools to assist researchers in identifying study design flaws that undermine the validity of causal inferences. We propose a conceptual framework for LLMs as causal co-pilots that encode domain knowledge across various fields, engaging with researchers in natural language interactions to provide contextualized assistance in study design. We provide illustrative examples of how LLMs can function as causal co-pilots, propose a structured framework for their grounding in existing causal inference frameworks, and highlight the unique challenges and opportunities in adapting LLMs for reliable use in epidemiological research.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation: Response is rather lengthy, not concise.

# %% [markdown]
# ### 3. Write a short, imaginative story (100–150 words) about a robot finding friendship in an unexpected place.

# %% [markdown]
# Aspect Tested: Engagement: Keep it interesting and relatable, and make the reader feel connected to the story.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation: Overall engaging, but varying descriptions, adding specific interactions, and emphasizing emotions would make it better.

# %% [markdown]
# ### 4. If a store sells apples in packs of 4 and oranges in packs of 3, how many packs of each do I need to buy to get exactly 12 apples and 9 oranges?

# %% [markdown]
# Aspect Tested: Accuracy: Get the facts right.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation: Response is accurate and calculations are correct - no holes here.

# %% [markdown]
# ### 5. Rewrite the following paragraph in a professional, formal tone…

# %% [markdown]
# Aspect Tested: Tone: Make it professional and formal.

# %% [markdown]
# Paragraph:
# Tom appeared on the sidewalk with a bucket of whitewash and a long-handled brush. He surveyed the fence, and all gladness left him and a deep melancholy settled down upon his spirit. Thirty yards of board fence nine feet high. Life to him seemed hollow, and existence but a burden. Sighing, he dipped his brush and passed it along the topmost plank; repeated the operation; did it again; compared the insignificant whitewashed streak with the far-reaching continent of unwhitewashed fence, and sat down on a tree-box discouraged. Jim came skipping out at the gate with a tin pail, and singing Buffalo Gals. Bringing water from the town pump had always been hateful work in Tom’s eyes, before, but now it did not strike him so. He remembered that there was company at the pump. White, mulatto, and negro boys and girls were always there waiting their turns, resting, trading playthings, quarrelling, fighting, skylarking. And he remembered that although the pump was only a hundred and fifty yards off, Jim never got back with a bucket of water under an hour – and even then somebody generally had to go after him.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation: The response successfully adopts a more professional and formal tone, replacing casual expressions with more sophisticated language.

# %% [markdown]
# ##### 🚧 Advanced Build:
#
# Please make adjustments to your application that you believe will improve the vibe check done above, push the changes to your HF Space and redo the above vibe check.

# %% [markdown]
# I made the following changes:
# 1. Expanded the System Template to include:
# - Structure requirements (overview, sections, lists)
# - Communication style (tone adaptation, clarity, technical vs creative)
# - Depth and clarity specifications (technical vs creative content handling)
# - Quality control measures (purposeful responses, conciseness)
# - Code example formatting guidelines
# 2. Changed Model Settings:
# - Upgraded to GPT-4 for more sophisticated responses
# - Adjusted temperature for a better balance between creativity and precision
# - Increased max_tokens to allow for more detailed explanations
# - Fine-tuned penalties to reduce repetition and encourage diverse responses

# %% [markdown]
# ### 1. Explain the concept of object-oriented programming in simple terms to a complete beginner

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Evaluation: The response is much more thorough and easier to understand for a complete beginner. Code examples are also included which helps to clarify the concepts.

# %% [markdown]
# ### 2. Read the following paragraph and provide a concise summary of the key points…

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation: The response is much more concise while still providing a comprehensive summary of the key points.

# %% [markdown]
# ### 3. Write a short, imaginative story (100–150 words) about a robot finding friendship in an unexpected place.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation: Much more discriptive and emotionally engaging.

# %% [markdown]
# ### 4. If a store sells apples in packs of 4 and oranges in packs of 3, how many packs of each do I need to buy to get exactly 12 apples and 9 oranges?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation: Still accurate.  Better step by step explanation, but could be more concise.

# %% [markdown]
# ### 5. Rewrite the following paragraph in a professional, formal tone…

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Evaluation: The response successfully adopts a more professional and formal tone, but some sentences are quite long and complex - perhaps utilizing creativity improvements when not needed.
